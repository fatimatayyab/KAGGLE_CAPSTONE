# %% [markdown]
# # FinVibe — Experiments
# Scratch space for testing individual skills, agent prompts, and pipeline variations.
# Changes here do not affect the capstone submission.

# %%
import os
from dotenv import load_dotenv
load_dotenv(override=True)
print('API key:', 'set ✓' if os.environ.get('GOOGLE_API_KEY') else 'MISSING ✗')

# %%
# Quick skill smoke-test (no Gemini API needed)
from skills import get_stock_data, get_stock_news

print(get_stock_data('AAPL'))
print()
print(get_stock_news('AAPL'))

# %%
# Add experiment cells below
